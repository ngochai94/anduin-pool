# %% [markdown]
# # Anduin Billiard Stats

# %% [markdown]
# ### Rating changes overtime

# %%
import sys
sys.path.append('..')
from common.utils import *

tournament = init_tournament('../data/result.csv')
draw_rating_change(tournament)
# Out:
#             0     1     2     3     4     5     6     7     8
# cuong    1400  1488  1705  1907  1888  2008  2034  2095  1982
# nguyen   1400  1342  1473  1534  1804  1808  1845  1910  1958
# triet    1400  1648  1734  1800  1851  1881  1892  1913  1910
# quang    1400  1502  1411  1599  1547  1667  1663  1685  1888
# hai      1400  1502  1632  1583  1564  1596  1592  1652  1860
# hiep     1400  1648  1557  1508  1763  1757  1784  1756  1772
# keimoon  1400  1342  1428  1494  1545  1539  1578  1645  1693
# tuananh  1400  1488  1705  1766  1713  1719  1732  1704  1614
# nhi         0     0     0     0     0     0     0  1400  1307
# ngheo       0     0     0     0     0     0     0  1400  1307

# %% [markdown]
# ### Ranking changes overtime

# %%
draw_ranking_change(tournament)
# Out:
#          0  1  2  3  4  5  6   7   8
# cuong    1  5  2  1  1  1  1   1   1
# nguyen   2  7  6  6  3  3  3   3   2
# triet    3  1  1  2  2  2  2   2   3
# quang    4  3  8  4  7  6  6   6   4
# hai      5  4  4  5  6  7  7   7   5
# hiep     6  2  5  7  4  4  4   4   6
# keimoon  7  8  7  8  8  8  8   8   7
# tuananh  8  6  3  3  5  5  5   5   8
# nhi      -  -  -  -  -  -  -   9   9
# ngheo    -  -  -  -  -  -  -  10  10

# %% [markdown]
# ### Most unexpected/expected match result

# %%
pd.set_option('display.max_rows', 10)
get_match_prob(tournament)
# Out:
#          Winner team        Loser team  Season Probability
# 0        quang + hai   cuong + tuananh       8        2.9%
# 1      nguyen + hiep       cuong + hai       4        7.2%
# 2        quang + hai      triet + hiep       8        8.8%
# 3   nguyen + keimoon   cuong + tuananh       8       13.9%
# 4      nguyen + hiep   triet + keimoon       4       20.8%
# ..               ...               ...     ...         ...
# 28      triet + hiep  nguyen + keimoon       8       70.2%
# 29      cuong + hiep   triet + tuananh       6       73.2%
# 30  nguyen + tuananh    hiep + keimoon       5       79.5%
# 31   triet + tuananh  nguyen + keimoon       6       83.4%
# 32      cuong + hiep       quang + hai       6       97.4%
#
# [33 rows x 4 columns]

# %% [markdown]
# ### Individual summary by match tier

# %%
sns.set(style='white')
draw_sf_summary(tournament)
draw_wf_summary(tournament)
draw_lf_summary(tournament)
draw_overall_summary(tournament)

# %% [markdown]
# ### Win/lost by team composition

# %%
draw_team_summary(tournament)
